# %%
import sys
# !{sys.executable} -m pip install spacy
# !{sys.executable} -m pip install nltk
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python2.7/site-packages (2.0.11)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python2.7/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /usr/local/lib/python2.7/site-packages (from spacy) (0.28.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python2.7/site-packages (from spacy) (1.13.1)
# Requirement already satisfied: thinc<6.11.0,>=6.10.1 in /usr/local/lib/python2.7/site-packages (from spacy) (6.10.2)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /usr/local/lib/python2.7/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: pathlib in /usr/local/lib/python2.7/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: regex==2017.4.5 in /usr/local/lib/python2.7/site-packages (from spacy) (2017.4.5)
# Requirement already satisfied: ujson>=1.35 in /usr/local/lib/python2.7/site-packages (from spacy) (1.35)
# Requirement already satisfied: cymem<1.32,>=1.30 in /usr/local/lib/python2.7/site-packages (from spacy) (1.31.2)
# Requirement already satisfied: dill<0.3,>=0.2 in /usr/local/lib/python2.7/site-packages (from spacy) (0.2.7.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python2.7/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (1.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python2.7/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (1.10.11)
# Requirement already satisfied: msgpack-numpy==0.4.1 in /usr/local/lib/python2.7/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python2.7/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (4.23.0)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in /usr/local/lib/python2.7/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (1.10.0)
# Requirement already satisfied: cytoolz<0.9,>=0.8 in /usr/local/lib/python2.7/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (0.8.2)
# Requirement already satisfied: msgpack-python in /usr/local/lib/python2.7/site-packages (from thinc<6.11.0,>=6.10.1->spacy) (0.5.6)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python2.7/site-packages (from cytoolz<0.9,>=0.8->thinc<6.11.0,>=6.10.1->spacy) (0.9.0)
# Requirement already satisfied: nltk in /usr/local/lib/python2.7/site-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python2.7/site-packages (from nltk) (1.10.0)

# %%
# the imports used in A2
import re
# import json
from glob import glob
import os
from io import StringIO
from itertools import groupby
import pickle

import numpy as np
# import bs4
# %matplotlib inline
# import matplotlib.pyplot as plt
# Imports that might help with various functionality
import functools
import operator

# Additional imports from A3
from __future__ import print_function
import math
from collections import defaultdict
# from nltk.tokenize import TreebankWordTokenizer
# import Levenshtein  # package python-Levenshtein

# Additional imports from A5
import nltk
# nltk.download()
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# import Empath
# from empath import Empath
# lexicon = Empath()

# import spacy

import spacy
nlp = spacy.load('en')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mayzhou/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# import sys
# # Ensure that your kernel is using Python3
# # assert sys.version_info.major == 3
# reload(sys)

# %%
# import the json
import json
with open("data3copy.json", "r") as f:
    women_summaries = json.load(f)
    
# print(women_summaries)
# women_summaries is the json file imported
# it's of the form [{'views' : num_views, 'name' : woman_name, 'summary' : woman_summary}, ...]
# a list of dictionaries of women

# %%
# creates a list of women to keep as a global variable
women_names = list()
for i in range(len(women_summaries)):
    name = women_summaries[i]['name']
    end_index = name.find('(')
    if end_index != -1 and name[: (end_index-1)] not in women_names :
        women_names.append(name[: (end_index-1)])
    elif end_index == -1 and name not in women_names :
        women_names.append(name)
        
print(women_names)
#women_names is a list of the names of women in order of the JSON file
# Out:
# [u'Mary Anning', u'Lilias Armstrong', u'Ann Bannon', u'Rachel Carson', u'Ursula Franklin', u'Barbara McClintock', u'Margaret Murray', u'Elizabeth Alexander', u'Jean Bartik', u'Brigitte Boisselier', u'Gerty Cori', u'Marie Curie', u'Joan Curran', u'Natasha Falle', u'Maria Goeppert-Mayer', u'Hypatia', u'Frances Oldham Kelsey', u'Hina Rabbani Khar', u'Judith Krug', u'Henrietta Swan Leavitt', u'Helen Mayo', u'Rosalie Slaughter Morton', u'Pamela C. Rasmussen', u'Dorothy P. Rice', u'Vera Rubin', u'Margaret Thatcher', u'Hoylande Young', u'Ruth Kelly', u'Elsie MacGill', u'Andrea Ablasser', u'Suhayya Abu-Hakima', u'Alice Agogino', u'In-Young Ahn', u'Fay Ajzenberg-Selove', u'Nora Lilian Alcock', u'Claudia Alexander', u'Alice Alldredge', u'Heather C. Allen', u'Margaret Allen', u'Yasmin Altwaijri', u'Rommie Amaro', u'Mary Amdur', u'Adelaide Ames', u'Frances Ames', u'Naomi Amir', u'Angelika Amon', u'Nalini Anantharaman', u'Elda Emma Anderson', u'Gloria Long Anderson', u'Sharon Anderson', u'Brenda Andrews', u'Marimba Ani', u'Mary Louisa Armitt', u'Audrey Arnott', u'Valerie Aurora', u'Myrtle Bachelder', u'Jean Bacon', u'Anna Baetjer', u'Susan Bailey', u'Alice Ball', u'Anne Elizabeth Ball', u'Mary Elizabeth Barber', u'Mary Barber', u'Kathrin Barboza Marquez', u'Ida Barney', u'Dorothea Bate', u'Grace Bates', u'Sarah Bavly', u'Diana Beck', u'Lydia Becker', u'Kay Behrensmeyer', u'Anne Beloff-Chain', u'Katherine Belov', u'Elissa P. Benedek', u'Magdalena Bermejo', u'M\xf3nica Bettencourt-Dias', u'Agathe L. van Beverwijk', u'Rosemary Biggs', u'Leonora Bilger', u'Caroline Birley', u'Ann Bishop', u'Margaret Blackwood', u'Cicely Pearl Blair', u'Dorothy Blum', u'Berta Bobath', u'Antje Boetius', u'Diana Marcela Bola\xf1os Rodriguez', u'Tami Bond', u'Louise Bourgeois Boursier', u'Cecilia Bouzat', u'Ann T. Bowling', u'Alice Bowman', u'Helen Boyle', u'Maria Eugenia Bozzoli', u'Mary Katharine Brandegee', u'Sara Branham Matthews', u'Nina Starr Braunwald', u'Victoria Bricker', u'Angela Hartley Brodie', u'Mary Brodrick', u'Elizabeth M. Bryan', u'Louise Stevens Bryant', u'Lucy Meredith Bryce', u'Mary Buckland', u'Edith B\xfclbring', u'Nancy Tyson Burbidge', u'Gertrude Simmons Burlingham', u'Nathalie Cabrol', u'Doris Calloway', u'Ella Orr Campbell', u'Mary Cannon', u'Nessa Carey', u'Margery C. Carlson', u'Janet Carr', u'Elena Cattaneo', u'Colleen Cavanaugh', u'June Chan', u'Nancy T. Chang', u'Xuemei Chen', u'Graciela Chichilnisky', u'Jennifer Childs-Roshak', u'Shya Chitaley', u'Carol Chomsky', u'Edith Claypole', u'Mary Strong Clemens', u'Edith Clements', u'Kim Cobb', u'Doris Mable Cochran', u'Jane Colden', u'Louisa Collings', u'Mary Collins', u'Tina Cooper', u'Vivienne Cassie Cooper', u'Catherine Corrigan', u'Kendra Coulter', u'Mary M. Crawford', u'Jacqueline Crawley', u'Aleen Cust', u'Marie Darby', u'Blanche Evans Dean', u'Fe del Mundo', u'Maude Delap', u'C\xe9cile DeWitt-Morette', u'Liebe Sokol Diamond', u'Mary Cynthia Dickerson', u'Elaine Didier', u'Amalie Dietrich', u'Judith Donath', u'Klara D\xf6pel', u'Marie-Louise Dubreil-Jacotin', u'Moon Duchin', u'Suzanne Duigan', u'Ioana Dumitriu', u'Moira Dunbar', u'Rachael Dunlop', u'Florence Margaret Durham', u'Helen Dyer', u'Janice Eberly', u'Lina Eckenstein', u'Tilly Edinger', u'Cecile Hoover Edwards', u'Grace Eldering', u'Constance Ellis', u'Theresa Elmendorf', u'Victoria Joyce Ely', u'Gladys Anderson Emerson', u'Rica Erickson', u'Ethel Bellamy', u'Vera Faddeeva', u'Lesley Fallowfield', u'Adeyinka Gladys Falusi', u'Maxine Fassberg', u'Daphne Gail Fautin', u'Olga Fedchenko', u'Elizabeth J. Feinler', u'Genevieve Grotjan Feinstein', u'List of female Fellows of the Royal Society', u'Catherine Clarke Fenselau', u'Angella D. Ferguson', u'Joan Feynman', u'Kathryn Ferguson Fink', u'Rita Sapiro Finkler', u'Mabel Purefoy FitzGerald', u'Justina Ford', u'Laura Forster', u'Susannah Fox', u'Frieda Fraser', u'Helen Freedhoff', u'Ida Freund', u'\u0141ucja Frey', u'Helen Fricker', u'Rose Gaffney', u'Kadambini Ganguly', u'Pamela L. ...

# %%
# Builds a dictionary that maps woman to the list of tokens associated with her
# {'woman1' : ['token1', 'token2', ... 'tokenn']}

def build_spacy_token_dictionary(input_summaries, input_women_names):
    # Builds a dictionary that maps each woman to their tokenized words (yes we've already done this but we want the spacy version)
    women_token_dictionary = dict()
    
    for i in range(len(women_names)):
        name = women_names[i]
        summary = women_summaries[i]['summary']
    
        index_was = summary.find('was ')
        index_is = summary.find('is ')
        index_currently = summary.find('currently ')
        if (index_was == -1 and index_is == -1):
            summary2 = summary[index_currently:]
        elif (index_was == -1 and index_currently == -1):
            summary2 = summary[index_is:]
        elif (index_is == -1 and index_currently == -1):
            summary2 = summary[index_was:]
        else :
            index_min = min(index_is, index_was)
            summary2 = summary[index_min:]
            
        summary_lower = summary2.lower()
        summary_token = nlp(summary_lower)
        summary_list = [token.text for token in summary_token] # Converts to list
        summary_token_filtered = [w for w in summary_list if w not in stopwords.words('english')]
        summary_retoken = 
        
        regex_non_word = re.compile(r'[^\W]')
        summary_final = filter(regex_non_word.search, summary_token_filtered)
        women_token_dictionary[name] = summary_final
        
    return women_token_dictionary

# %%
women_token_dictionary = build_spacy_token_dictionary(women_summaries, women_names)
print(women_token_dictionary)
# Out:
# {u'Danielle Feinberg': [u'turkish', u'american', u'electrical', u'computer', u'engineer', u'professor', u'wireless', u'technology', u'researcher', u'new', u'york', u'university'], u'Frederica Darema': [u'chinese', u'born', u'american', u'businesswoman', u'director', u'co', u'founder', u'former', u'president', u'marvell', u'technology', u'group', u'dai', u'considered', u'one', u'successful', u'women', u'entrepreneurs', u'female', u'co', u'founder', u'major', u'semiconductor', u'company', u'2015', u'listed', u'95th', u'powerful', u'woman', u'world', u'forbes'], u'Genevieve Bell': [u'australian', u'anthropologist', u'best', u'known', u'work', u'intersection', u'cultural', u'practice', u'technology', u'development', u'professor', u'bell', u'director', u'autonomy', u'agency', u'assurance', u'3a', u'institute', u'co', u'founded', u'australian', u'national', u'university', u'anu', u'csiro', u'\u2019s', u'data61', u'bell', u'named', u'university', u"'s", u'inaugural', u'florence', u'violet', u'mckenzie', u'chair', u'honour', u'australia', u"'s", u'first', u'female', u'electrical', u'engineer', u'bell', u'senior', u'fellow', u'intel', u'formerly', u'vice', u'president', u'directing', u'company', u"'s", u'corporate', u'sensing', u'insights', u'group', u'widely', u'published', u'holds', u'13', u'patents'], u'Hinke Osinga': [u'dutch', u'mathematician', u'expert', u'dynamical', u'systems', u'works', u'professor', u'applied', u'mathematics', u'university', u'auckland', u'new', u'zealand', u'well', u'research', u'known', u'creator', u'mathematical', u'art'], u'Dorothy Maharam': [u'taiwanese', u'mathematician', u'works', u'professor', u'mathematics', u'columbia', u'university', u'research', u'interests', u'include', u'algebraic', u'geometry', u'symplectic', u'geometry', u'liu', u'graduated', u'national', u'taiwan', u'university', u'1996', u'earned', u'ph.d', u'2002', u'harvard', u'university', u'supervision', u'shing', u'tung', u'yau', u'continuing', u'harvard', u'junior', u'fellow', u'took', u'faculty', u'position', u'northwestern', u'university', u'moved', u'columbia', u'2006', u'liu', u'morningside', u'silver', u'medal', u'2007', u'invited', u'speaker', u'international', u'congress', u'mathematicians', u'2010', u'2012', u'became', u'one', u'inaugural', u'fellows', u'american', u'mathematical', u'society'], u'Anne Johnson': [u'american', u'actress', u'impressionist', u'starred', u'film', u'television', u'known', u'roles', u'nadine', u'hudson', u'thomas', u"'s", u'happening', u'aileen', u'lewis', u'double', u'trouble', u'althea', u'tibbs', u'heat', u'night', u'cast', u'member', u'living', u'color', u'final', u'season'], u'Susan Gal': [u'mae', u'sidney', u'g.', u'metzl', u'distinguished', u'service', u'professor', u'anthropology', u'linguistics', u'social', u'sciences', u'university', u'chicago', u'author', u'co', u'author', u'several', u'books', u'numerous', u'articles', u'linguistic', u'anthropology', u'language', u'gender', u'social', u'history', u'eastern', u'europe', u'book', u'politics', u'gender', u'socialism', u'susan', u'gal', u'gail', u'kligman', u'2001', u'heldt', u'prize', u'awarded', u'american', u'association', u'advancement', u'slavic', u'studies', u'2002', u'gal', u'awarded', u'guggenheim', u'fellowship', u'study', u'language', u'ideologies', u'political', u'authority', u'socialism', u'2007', u'gal', u'elected', u'american', u'academy', u'arts', u'sciences'], u'Leslie P. Kaelbling': [u'figure', u'free', u'software', u'founded', u'many', u'startups', u'silicon', u'valley', u'husband', u'william', u'lynne', u'jolitz', u'probably', u'famous', u'work', u'pioneering', u'open', u'source', u'operating', u'systems', u'386bsd', u'husband', u'founded', u'startup', u'companies', u'involve', u'workstations', u'companies', u'internet', u'multimedia', u'lynne', u'also', u'noted', u'author', u'authority', u'operating', u'systems', u'networking', u'issues', u'lynne', u'internet', u'news', u'media', u'commentator', u'discussing', u'events', u' ...

# %%
def build_sim_matrix(input_token_dictionary, input_len_names):
    # Builds matrix using spacy that stores each woman's cosine similarity to each other
    
    sim_matrix = np.zeros(shape = (input_len_names, input_len_names))
    
    for woman1 in input_token_dictionary:
        for woman2 in input_token_dictionary:
            
            sim_matrix[woman1][woman2] = input_token_dictionary[woman1].similarity(input_token_dictionary[woman2])

# %%
women2women_cosine_sim_matrix = build_sim_matrix(women_token_dictionary, len(women_names))
print(women2women_cosine_sim_matrix)
# Out:
# --------------------------------------------------------
# AttributeError         Traceback (most recent call last)
# <ipython-input-37-fc517241c3b4> in <module>()
# ----> 1 women2women_cosine_sim_matrix = build_sim_matrix(women_token_dictionary, len(women_names))
#       2 print(women2women_cosine_sim_matrix)
#
# <ipython-input-36-d6acf8b66cbf> in build_sim_matrix(input_token_dictionary, input_len_names)
#       6     for woman1 in input_token_dictionary:
#       7         for woman2 in input_token_dictionary:
# ----> 8             sim_matrix[woman1][woman2] = input_token_dictionary[woman1].similarity(input_token_dictionary[woman2])
#
# AttributeError: 'list' object has no attribute 'similarity'

# %%
import operator

# Code taken from A5
def get_ranked_women(input_woman, input_sim_matrix, input_women_names) :
    '''Return sorted rankings (most to least similar) of women as 
        a list of two-element tuples, where the first element is the 
        woman's name and the second element is the similarity score
    '''
    
    # Get index from woman's name
    idx = input_women_names.index(input_woman)
    
    # Get list of similarity scores for woman
    score_lst = input_sim_matrix[idx]
    women_score_lst = [(input_women_names.index(index), s) for index, score in enumerate(score_lst)]
    
    # Do not account for woman herself in ranking
    women_score_lst = women_score_lst[:idx] + women_score_lst[idx+1:]
    
    # Sort rankings by score (most similar to least similar)
    women_score_lst = sorted(women_score_lst, key=lambda x: -x[1])
    
    # Only returning top 5!
    return women_score_lst[:5]


# Builds a 'top 5 most similar' list of woman for every woman
def create_top_5_dict_women(input_sim_mat, num_women, input_women_names):
    women_top5 = {}
    
    # Loop through each woman
    for woman in range(num_women):
        similarity_list = get_ranked_women(input_women_names[woman], input_sim_mat, input_women_names)
        women_top5[input_women_names[woman]] = similarity_list
        
    return women_top5

# %%
top5_dict_women2women = create_top_5_dict_women(women2women_cosine_sim_matrix, len(women_names), women_names)
# Out:
# --------------------------------------------------------
# NameError              Traceback (most recent call last)
# <ipython-input-13-7095f43c64ca> in <module>()
# ----> 1 top5_dict_women2women = create_top_5_dict_women(women2women_cosine_sim_matrix, len(women_names), women_names)
#
# NameError: name 'women2women_cosine_sim_matrix' is not defined

# %%
def return_query(input_query, input_women_token_dictionary):
    # Given a query string, this function will return a list of women that are most similar to the query
    
    query = nlp(input_query)
    results = [] # List that will eventually store name, similarity, popularity, and ultimate RANKING
    
    # Ranking will be defined by: (1/popularity) + (0.5*similarity) + entity weighting
    
    for woman in input_women_token_dictionary:
        similarity = query.similarity(input_women_token_dictionary[woman])
        if similarity > 0.2: # Arbitrary number, can play around with with
            results.append((woman, similarity, similarity)) # Currently similarity will act as the ranking
            
    results.sort(key=lambda x: x[2]) # Ascending order of rankings
    results.reverse() # Descending order

# %%
def sumWords(text): 
    wordDict = dict()
    for word in text :
        if word in wordDict :
            wordDict[word] = wordDict[word] + 1
        else :
            wordDict[word] = 1
    return (wordDict)

# %%
# create the global variable of what is equivalent to good_types
unique_word_lst = list()
for woman in women_dict_1sent :
    summary = women_dict_1sent[woman]
    for word in summary :
        if word not in unique_word_lst :
            unique_word_lst.append(word)

# %%
# creates a np array where the rows are women according to the list of women names
# columns are rows according to the list of unique words
def create_word_freq_array(input_women_dict_1sent, input_women_names, input_num_women, input_unique_word_lst):
    dict_freq = dict()

    for woman in input_women_dict_1sent :
        dict_freq[woman] = sumWords(input_women_dict_1sent[woman])
    
    np_with_freq = np.zeros(shape = (len(dict_freq), len(input_unique_word_lst)))
    i = 0
    for woman in input_women_names :
#         print(woman)
        if woman in dict_freq :
            j = 0
            for word in input_unique_word_lst :
                if word in dict_freq[woman] :
#                     print(j)
                    np_with_freq[i][j] = dict_freq[woman][word]
                j = j + 1
            i = i + 1
#     print(np_with_freq[0][0])
    return np_with_freq
#     print(input_unique_word_lst.index('chogha'))

# %%
word_freq_array = create_word_freq_array(women_dict_1sent, women_names, len(women_dict_1sent), unique_word_lst)

# %%
# The file is ordered from the homeworks that we've worked on
# so that we can easily go back to the specific assignment if we need to

# %%
# TODO: Need to account for a woman's profile mentioning another woman's name

# def create_j_sim_mat_women(input_num_women, input_word_freq_array, input_unique_word_lst):
#     arr = np.zeros(shape = (input_num_women, input_num_women))
    
#     for (i, woman1) in enumerate(input_word_freq_array) :
#         for (j, woman2) in enumerate(input_word_freq_array) :
#             s1 = np.nonzero(woman1)
#             s2 = np.nonzero(woman2)
#             intersect = np.intersect1d(s1, s2)
#             union = np.union1d(np.array(s1).flatten(), np.array(s2).flatten())
#             if len(union) > 0 :
#                 arr[i][j] = len(intersect)/len(union)
                
#     np.fill_diagonal(arr, 0)
    
# #     print(np.sum(arr[100:]))
#     return arr

# %%
# j_sim_mat_women = create_j_sim_mat_women(len(women_names), word_freq_array, unique_word_lst)

# %%
# import operator

# # make dictionary of top 5 women for each woman
# def create_top_5_dict_women(j_sim_mat, num_women):
#     women_top5 = {}
#     # Loop through each woman
#     for woman in range(num_women):
#         top_5 = []      
#         min_similarity = (-1, -1)
                
#         for i in range(num_women):
#             if (len(top_5) < 5): # Can just add bc we don't have top 5 yet
#                 top_5.append((i, j_sim_mat[woman][i])) # Stores (index, similarity)
#                 min_similarity = min(top_5, key = lambda t: t[1]) # Grabs tuple with minimum value
#             else: # Only add similarity if it is greater than the minimum similarity
#                 if (j_sim_mat[woman][i] > min_similarity[1]):
#                     top_5.remove(min_similarity) # Remove minimum similarity tuple
#                     top_5.append((i, j_sim_mat[woman][i])) # Stores new (index, similarity)
#                     min_similarity = min(top_5, key = lambda t: t[1]) # Grabs tuple with minimum value
                    
#         # Sort tuple list of top 5
#         top_5.sort(key = operator.itemgetter(1))
#         # Descending order
#         top_5.reverse()
        
#         top_5_names = []
        
#         for k, v in top_5:
#             top_5_names.append(women_names[k])
            
#         # Store woman (key) and list of top 5 most similar (value)
#         women_top5[women_names[woman]] = top_5_names
        
#     return(women_top5)

# %%
# # make dictionary of top 5 women for each word
# def create_top_5_dict_word(word_freq_array, num_words, num_women):
#     word_top5 = {}
#     # Loop through each word
#     for word in range(len(word_freq_array.T)): # Iterates through words first
#         top_5 = []      
#         min_similarity = (-1, 0)
                
#         for i in range(num_women):
#             if (word_freq_array.T[word][i] > min_similarity[1]):
#                 if (len(top_5) < 5):
#                     top_5.append((i, word_freq_array.T[word][i])) # Stores new (index, word count)
#                     min_similarity = min(top_5, key = lambda t: t[1]) # Grabs tuple with minimum value
#                 else:
#                     top_5.remove(min_similarity) # Remove minimum similarity tuple
#                     top_5.append((i, word_freq_array.T[word][i])) # Stores new (index, word count)
#                     min_similarity = min(top_5, key = lambda t: t[1]) # Grabs tuple with minimum value
                    
#         # Sort tuple list of top 5
#         top_5.sort(key = operator.itemgetter(1))
#         # Descending order
#         top_5.reverse()
        
#         top_5_names = []
        
#         for k, v in top_5:
#             top_5_names.append(women_names[k])
            
#         # Store word (key) and list of top 5 most similar (value)
#         word_top5[unique_word_lst[word]] = top_5_names
        
#     return(word_top5)

# %%
# top_5_dict_women = create_top_5_dict_women(j_sim_mat_women, len(women_names))
# top_5_dict_words = create_top_5_dict_word(word_freq_array, len(unique_word_lst), len(women_names))
# print(top_5_dict_words)
# Out:
# {'english': ['Lilias Armstrong', 'Mary Anning'], 'fossil': ['Mary Anning'], 'collector': ['Mary Anning'], 'dealer': ['Mary Anning'], 'paleontologist': ['Mary Anning'], 'became': ['Phyllis Morse', 'Aleksandra Dunin-Wąsowicz', 'Chien-Shiung Wu', 'Olga Tufnell', 'Natasha Falle'], 'known': ['Madeline Kneberg Lewis', 'Mary Anning'], 'around': ['Mary Anning'], 'world': ['Lisa Curran', 'Salinee Tavaranan', 'Marie Curie', 'Mary Anning'], 'important': ['Mary Anning'], 'finds': ['Jeanne Guillemin', 'Mary Anning'], 'made': ['Mary Anning'], 'jurassic': ['Mary Anning'], 'marine': ['Mary Katharine Brandegee', 'Alice Bowman', 'Ynes Mexia', 'Patricia Lindop', 'Margaret Allen'], 'beds': ['Mary Anning'], 'cliffs': ['Mary Anning'], 'along': ['Mary Anning'], 'channel': ['Mary Anning'], 'lyme': ['Mary Anning'], 'regis': ['Mary Anning'], 'county': ['Susan M. Ervin-Tripp', 'Janet Bennion', 'Myra Keen', 'Mary Anning'], 'dorset': ['Mary Anning'], 'southwest': ['Mary Anning'], 'england.': ['Mary Anning'], 'findings': ['Mary Anning'], 'contributed': ['Dorothy P. Rice', 'Mary Anning'], 'changes': ['Mary Anning'], 'scientific': ['Mary Anning'], 'thinking': ['Mary Anning'], 'prehistoric': ['K. Aslihan Yener', 'Mary Anning'], 'life': ['Mary Anning'], 'history': ['Barbara Harrell-Bond', 'Jean Lave', 'Annette Laming-Emperaire', 'Mary Anning'], 'earth.': ['Mary Anning'], 'anning': ['Mary Anning'], 'searched': ['Mary Anning'], 'fossils': ['Mary Anning'], 'area': ['Mary Anning'], "'s": ['Salinee Tavaranan', 'Hypatia', 'Computer Engineer Barbie', 'Natasha Falle', 'Ann Dunham'], 'blue': ['Mary Anning'], 'lias': ['Mary Anning'], 'particularly': ['Éva Pócs', 'Birutė Galdikas', 'Mary Anning'], 'winter': ['Mary Anning'], 'months': ['Mary Anning'], 'landslides': ['Mary Anning'], 'exposed': ['Mary Anning'], 'new': ['Ayten Aydın', 'Salinee Tavaranan', 'Jennifer Moody', 'Janet Bennion', 'Constance Goddard DuBois'], 'collected': ['Mary Anning'], 'quickly': ['Mary Anning'], 'lost': ['Linda Dégh', 'Mary Anning'], 'sea.': ['Mary Anning'], 'nearly': ['Mary Anning'], 'died': ['Judith Berman', 'Ayten Aydın', 'Mary Anning'], '1833': ['Mary Anning'], 'landslide': ['Mary Anning'], 'killed': ['Mary Anning'], 'dog': ['Mary Anning'], 'tray.': ['Mary Anning'], 'discoveries': ['Mary Anning'], 'included': ['Mary Anning'], 'first': ['Salinee Tavaranan', 'Kakani Katija Young', 'Marie Curie', 'Alice E. Gillington', 'Charlotte Sahl-Madsen'], 'ichthyosaur': ['Mary Anning'], 'skeleton': ['Mary Anning'], 'correctly': ['Mary Anning'], 'identified': ['Mary Anning'], 'two': ['Salinee Tavaranan', 'Ayten Aydın', 'Myeong-Hee Yu', 'Josephine Silone Yates', 'Marie Curie'], 'complete': ['Salinee Tavaranan', 'Mary Anning'], 'plesiosaur': ['Mary Anning'], 'skeletons': ['Mary Anning'], 'found': ['Janet Bennion', 'Mary Anning'], 'pterosaur': ['Mary Anning'], 'located': ['Mary Anning'], 'outside': ['Mary Anning'], 'germany': ['Merrill Swain', 'Joanne M. Maguire', 'Martha L. Ludwig', 'Cicely Pearl Blair', 'Hilde Levi'], 'fish': ['Mary Anning'], 'fossils.': ['Mary Anning'], 'observations': ['Mary Anning'], 'played': ['Mary Anning'], 'key': ['Mary Anning'], 'role': ['Margaret Conkey', 'Beatrice Blyth Whiting', 'Jane Wynne', 'Mary Anning'], 'discovery': ['Zeineb Benzina', 'Jean Briggs', 'Jennifer Childs-Roshak', 'Henrietta Swan Leavitt', 'Nessa Carey'], 'coprolites': ['Mary Anning'], 'bezoar': ['Mary Anning'], 'stones': ['Mary Anning'], 'time': ['Faye Ginsburg', 'Isabella Karle', 'Ivy Parker', 'Computer Engineer Barbie', 'Margaret Murray'], 'fossilised': ['Mary Anning'], 'faeces.': ['Mary Anning'], 'also': ['K. Aslihan Yener', 'Antonia Mills', 'Salinee Tavaranan', 'Janet Carr', 'Ann Dunham'], 'discovered': ['Olive Pink', 'Janet Bennion', 'Eileen Krige', 'Diana Marcela Bolaños Rodriguez', 'Ann Bishop'], 'belemnite': ['Mary Anning'], 'contained': ['Mary Anning'], 'ink': ['Mary Anning'], 'sacs': ['Mary Anning'], 'like': ['Madeline Kneberg Lewis', 'Mary Anning'], 'modern': ['Nadia Abu El Haj', 'Mary Anning'], 'cepha ...

# %%
# Homework 3 looked at Levenshtein distance (probably not a good idea imo)

# %% [markdown]
# THIS IS ALL EMPATH STUFF!

# %%
def women_categories(input_women_dict_1sent):
    categories = {}
    
    for woman in input_women_dict_1sent:
        list_of_categories = lexicon.create_category(woman, input_women_dict_1sent[woman])
        categories[woman] = list_of_categories

# %%
women_categories = women_categories(women_dict_1sent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f134b32aaaeb> in <module>()
# ----> 1 women_categories = women_categories(women_dict_1sent)
#       2 print(women_categories)
#
# NameError: name 'women_dict_1sent' is not defined

# %%
# def return_query(query, top_5_dict_words):
#     if query in women_names: # EX: 'is similar to Mary Jackson'
#         return(top_5_dict_women[query])
#     else: # EX: 'worked at NASA'
#         return(top_5_dict_words[query])

# %%
# Homework 4 looked at cosine similarity, which we can consider on top of jaccard

# %%
#print(return_query('nasa', top_5_dict_words))
# Out:
# ['Mary Jackson']

# %%
def unique_categories(input_women_categories):
    # Returns: list of unique string categories
    categories = []
    categories_set = set()
    for woman in input_women_categories:
        categories_set = categories_set & set(input_women_categories)
        
    categories = list(categories_set)

# %%
unique_categories = unique_categories(input_women_categories)

# %%
def return_empath_query_categories(query, input_unique_categories):
    return lexicon.analyze(query, categories=input_unique_categories) # Don't have to normalize for now

# %% [markdown]
# THIS IS ALL SPACY STUFF

# %%
# creates a dictionary {'name', [list of words in the summary]}
women_dict_1sent = dict()
# for i in range(len(women_summaries)):
#     name = women_summaries[i]['name']
for i in range(len(women_names)):
    name = women_names[i]
    summary = women_summaries[i]['summary']
    # to do: 
    # hardcoded the words that we're looking for
    # change to regex later time
    index_was = summary.find('was ')
    index_is = summary.find('is ')
    index_currently = summary.find('currently ')
    if (index_was == -1 and index_is == -1):
        summary2 = summary[index_currently:]
        # index_period = summary2.find('.')
        # first_sent = summary2[:index_period]
    elif (index_was == -1 and index_currently == -1):
        summary2 = summary[index_is:]
        # index_period = summary2.find('.')
        # first_sent = summary2[:index_period]
    elif (index_is == -1 and index_currently == -1):
        summary2 = summary[index_was:]
        # index_period = summary2.find('.')
        # first_sent = summary2[:index_period]
    else :
        index_min = min(index_is, index_was)
        summary2 = summary[index_min:]
        # index_period = summary2.find('.')
        # first_sent = summary2[:index_period]
    # might want to change if we use ML that finds proper nouns
    # implement a stemmer
    first_sent_lower = summary2.lower()
    tokenizer = TreebankWordTokenizer()
    first_sent_tok = tokenizer.tokenize(first_sent_lower)
    filtered_first_sent = [w for w in first_sent_tok if w not in stopwords.words('english')]
    
    regex_non_word = re.compile(r'[^\W]')
    filtered_final = filter(regex_non_word.search, filtered_first_sent)

    women_dict_1sent[name] = list(filtered_final)
    print(name)
    print(women_dict_1sent[name])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-be43ff12fe64> in <module>()
#      32     # implement a stemmer
#      33     first_sent_lower = summary2.lower()
# ---> 34     tokenizer = TreebankWordTokenizer()
#      35     first_sent_tok = tokenizer.tokenize(first_sent_lower)
#      36     filtered_first_sent = [w for w in first_sent_tok if w not in stopwords.words('english')]
#
# NameError: name 'TreebankWordTokenizer' is not defined
